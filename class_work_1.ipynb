# %% [markdown]
# Q1. find the sum ?

# %%
num1 = 40
num2 = 50 
total = num1+num2
print("Total:",total)
# Out:
# Total: 90

# %% [markdown]
#  Q2. Find the difference between 50 and 18 ?

# %%
num1 = 50 
num2 = 18
num3 = num1 - num2
print("Difference:",num3)
# Out:
# Difference: 32

# %% [markdown]
# Q3. Find the product of 9 and 7 ?

# %%
num1 = 9 
num2 = 7
num3 = 9*7
print("Product:",num3)
# Out:
# Product: 63

# %% [markdown]
# Q4. Find the remainder when 5000 in divided by 2?

# %%
num1 = 5000 
num2 = 2
num3 = 5000%2
print("Remainder:",num3)
# Out:
# Remainder: 0

# %% [markdown]
# Q5. Find the square of 12 using the power operator ?

# %%
num1 = 12
square = num1 ** 2
print("Square is :",square)
# Out:
# Square is : 144

# %% [markdown]
# Q6. Find the cube of 5 using the power operator ?

# %%
num1 = 5
cube = num1 ** 3
print("Cube is:",cube)
# Out:
# Cube is: 125

# %% [markdown]
# Q7. Find the floor division result when 29 is divide by 5 ?

# %%
num1 = 29
num2 = 5
num3 = num1 // num2
print(" Floor Division is :",num3)
# Out:
#  Floor Division is : 5

# %% [markdown]
# Q8. Check whether 10 is greater then 5?

# %%
num1 = 10 
num2 = 5 
print("10 is greater then 5:=",num1>num2)
# Out:
# 10 is greater then 5:= True

# %% [markdown]
# Q9. Check whether 15 is less than 25. ?

# %%
num1 = 15
num2  = 25
print(num1 < num2)
# Out:
# True

# %% [markdown]
# Q10. Check whether 20 is equal to 20 ?

# %%
num1 = 20 
num2 = 20 
print(num1 == num2)
# Out:
# True

# %% [markdown]
# Q11. Check whether 30 is not equal to 10 ?

# %%
num1 = 30
num2 = 10 
print(num1 != num2)
# Out:
# True

# %% [markdown]
# Q12. Check whether 45 is greater than or equal to 40 ?

# %%
num1 = 45 
num2 = 40 
print(num1 >= num2)
# Out:
# True

# %% [markdown]
# Q13. Check whether 8 is less than or equal to 3 ?

# %%
num1 = 8 
num2 = 3 
print(num1 <= num2)
# Out:
# False

# %% [markdown]
# Logical operator

# %% [markdown]
#  Q14. Check the result of True and False ?

# %%
print(True  and False )
# Out:
# False

# %% [markdown]
# Q15 . Check the result of True or False ?

# %%
print(True and False)
# Out:
# False

# %% [markdown]
#  Q16. Check the result of not True ?

# %%
print(not True)
# Out:
# False

# %% [markdown]
# Q17. Check the result of not False.

# %%
print(not False)
# Out:
# True

# %% [markdown]
# Q18. Start with x = 20 and decrease its value by 4.

# %%
x = 20
#x = x - 4
x -= 4
print(x)
# Out:
# 16

# %% [markdown]
# Q19. Start with x = 6 and multiply it by 3.

# %%
x = 6
#x = x*3
x *= 3
print(x)
# Out:
# 54

# %% [markdown]
# Q20. Start with x = 40 and divide it by 2.

# %%
x = 40
#x = x/2
x /= 2
print(x)
# Out:
# 10.0

# %% [markdown]
# Q21. Start with x = 5 and raise it to the power 2.

# %%
x = 5
x **= 2
print(x)
# Out:
# 25

# %% [markdown]
# Q23. Start with x = 20 and divide by 3 to find the remainder.

# %%
x = 20
x %= 3
print(x)
# Out:
# 2

# %% [markdown]
# Q24. Check whether a = 10 and b = 10 are the same object using is ?

# %%
a = 10
b = 10
print(a is b)
#print(a == b)
# Out:
# True

# %% [markdown]
# Q25. whether a = [1, 2, 3] and b = [1, 2, 3] are the same object using is ?

# %%
a = [1, 2, 3] 
b = [1, 2, 3]
print(a is b)
#print(a == b)
#print(a is not b)
# Out:
# False
# True

# %% [markdown]
# Q26. Check whether a and b are not the same object using is not ?

# %%
a = 10
b = 10
print(a is b)
print(a is not b)
# Out:
# True
# False

# %% [markdown]
# Q26 . Check whether the letter 'a' is present in the string "apple" ?

# %%
word = "apple"
print('a' in word)
print('p' in word)
print('e' in word)
print('m' in word)
# Out:
# True
# True
# True
# False

# %% [markdown]
# Q27. Check whether the letter 'x' is not present in the string
# "python" ?

# %%
word = "python"
print('x' not in word)
print('p'  in word)
print('o' not in word)
# Out:
# True
# True
# False

# %% [markdown]
# Q28. Check whether the number 3 is present in the list [1, 2, 3, 4, 5] ?

# %%
num =  [1, 2, 3, 4, 5]
print(3 in num)
# Out:
# True

# %% [markdown]
# Q29. 45 & 54 result Bitwise  and ?

# %%
a = 45
b = 54
print(a & b)
# Out:
# 36

# %% [markdown]
# Q30. 45 | 54 result Bitwise or

# %%
a = 45
b = 54
print(a | b)
# Out:
# 63

# %% [markdown]
# Q31. 45^54 result Bitwise XOR ?

# %%
a = 45
b = 54
print(a^b)
# Out:
# 27

# %%
a = True
print(a:=False)
print(a:=False)
# print(a = False)
# Out:
# False
# False
